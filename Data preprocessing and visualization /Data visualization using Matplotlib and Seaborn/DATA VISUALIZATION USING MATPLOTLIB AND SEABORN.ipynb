# %%
#IN THIS NOTEBOOK WE WILL GO THROUGH DATA VISUALIZATION USING MATPLOTLIB AND SEABORN

# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/wr/3d4psf0d329973xgq3nmjhk00000gn/T/ipykernel_77610/3144141588.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/wr/3d4psf0d329973xgq3nmjhk00000gn/T/ipykernel_77610/3144141588.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/wr/3d4psf0d329973xgq3nmjhk00000gn/T/ipykernel_77610/3144141588.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/wr/3d4psf0d329973xgq3nmjhk00000gn/T/ipykernel_77610/3144141588.py", line 2, in <module>
#     import pandas as pd
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 60, in <module>
#     from pandas.core import (
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/harshjavia/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: pandas>=0.25 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from seaborn) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
df_sales = pd.read_excel("linechart.xlsx")
df_sales.head()
# Out:
#    Quarter  Fridge  Dishwasher  Washing Machine
# 0  Q1 2022    12.5         8.0              9.2
# 1  Q2 2022    11.0         7.5              8.5
# 2  Q3 2022    13.2         9.0              7.5
# 3  Q4 2022    16.4        11.0              7.6
# 4  Q1 2023    13.8         9.5              6.8

# %%
pip install --upgrade numpy matplotlib
# Out:
# Requirement already satisfied: numpy in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: matplotlib in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/harshjavia/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Line Chart

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(12,4))
plt.plot(df_sales["Quarter"], df_sales["Fridge"], color="blue", label="Fridge")
plt.plot(df_sales["Quarter"], df_sales["Dishwasher"], color="orange", label="Dishwasher")
plt.plot(df_sales["Quarter"], df_sales["Washing Machine"], color="green", label="Washing Machine")

plt.title("Product Sales")
plt.xlabel("Quarter")
plt.ylabel("Million $")

plt.legend()

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Pie Chart

# %%
total_sales = df_sales[["Fridge","Dishwasher","Washing Machine"]].sum()
total_sales
# Out:
# Fridge             80.9
# Dishwasher         53.0
# Washing Machine    45.6
# dtype: float64

# %%
plt.pie(total_sales, labels=total_sales.index, autopct='%1.1f%%', startangle=140, explode=(0.1,0,0), shadow=True)
plt.show()

# %% [markdown]
# # Bar Chart

# %%
df_sales.plot(kind="bar", x="Quarter")

plt.xticks(rotation=45)
plt.show()

# %%
df_sales_2 = df_sales.set_index("Quarter")
df_sales_2
# Out:
#          Fridge  Dishwasher  Washing Machine
# Quarter
# Q1 2022    12.5         8.0              9.2
# Q2 2022    11.0         7.5              8.5
# Q3 2022    13.2         9.0              7.5
# Q4 2022    16.4        11.0              7.6
# Q1 2023    13.8         9.5              6.8
# Q2 2023    14.0         8.0              6.0

# %%
df_sales_2.plot(kind="bar")
plt.xticks(rotation=45)
plt.show()

# %%
df_sales_2.plot(kind="barh")
plt.show()

# %%
df_score = pd.read_excel("histograms.xlsx")
df_score.head(3)
# Out:
#       Name  Exam_Score
# 0    Aarav          45
# 1  Michael          71
# 2    Bilal          59

# %% [markdown]
# # Histogram

# %%
plt.hist(df_score["Exam_Score"], density=True)
plt.show()
